# %% [markdown]
# # Model Inference
#
# Bagian ini saya melakukan inference untuk memprediksi harga mobil bekas yang ingin dijual.

# %% [markdown]
# # Import Libraries

# %%
import pickle
import pandas as pd

# %%
with open('deployment/model_xbg_r.pkl', 'rb') as file:
    model = pickle.load(file)

# %% [markdown]
# Load pipeline ke variable model

# %%
model
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('pipe_numerik',
#                                                   Pipeline(steps=[('capping',
#                                                                    Winsorizer(capping_method='iqr',
#                                                                               fold=3,
#                                                                               tail='both',
#                                                                               variables=['engine_capacity'])),
#                                                                   ('scaling',
#                                                                    StandardScaler())]),
#                                                   ['odometer_value',
#                                                    'year_produced',
#                                                    'engine_capacity',
# ...

# %% [markdown]
# Cell menampilkan bentuk pipeline.

# %%
data_inf = {
    'manufacturer_name': 'Toyota',
    'model_name': 'Corolla',
    'transmission': 'automatic',
    'color': 'black',
    'engine_fuel': 'gasoline',
    'engine_type': 'gasoline',
    'engine_capacity': 1.8,
    'body_type': 'sedan',
    'drivetrain': 'front',
    'odometer_value': 85000,
    'year_produced': 2015,
    'number_of_photos': 10,
    'up_counter': 3,
    'duration_listed': 45,
    'has_warranty': False,
    'is_exchangeable': True,
    'state': 'owned',
    'manufacturer_region': 'Japanese',
    'engine_has_gas': True,
    'car_age': 10
}
df_inf = pd.DataFrame([data_inf])
df_inf
# Out:
#   manufacturer_name model_name transmission  color engine_fuel engine_type  \
# 0            Toyota    Corolla    automatic  black    gasoline    gasoline
#
#    engine_capacity body_type drivetrain  odometer_value  year_produced  \
# 0              1.8     sedan      front           85000           2015
#
#    number_of_photos  up_counter  duration_listed  has_warranty  \
# 0                10           3               45         False
#
#    is_exchangeable  state manufacturer_region  engine_has_gas  car_age
# 0             True  owned            Japanese            True       10

# %%
model.predict(df_inf)
# Out:
# array([14522.004], dtype=float32)

# %% [markdown]
# Bedasarkan hasil prediksi, harga jual mobil Toyota bekas adalah 14.522 dolar.
